# %% [markdown]
# <a href="https://colab.research.google.com/github/matkeii/THC/blob/main/Clase_26_octubre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xpoints = np.array([0,6])
ypoints = np.array([0,250])

plt.plot(xpoints, ypoints)
plt.show()

# %%
xpoints = np.array([0,6])
ypoints = np.array([0,250])

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
xpoints = np.array([1,2,6,8])
ypoints = np.array([3,8,1,10])

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10, 5, 7])

plt.plot(ypoints,'o')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10, 5, 7])

plt.plot(ypoints,'X')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10, 5, 7])

plt.plot(ypoints,'D:m')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10, 5, 7])

plt.plot(ypoints,'*-b', ms = 20)
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10, 5, 7])

plt.plot(ypoints, marker ='X', ms = 20, mec ='m')
plt.show()

# %%
y1 = np.array([3,8,1,10])
y2 = np.array([6,2,7,11])

plt.plot(y1)
plt.plot(y2)

# %%
x1 = np.array([0, 1, 2, 3])
y1 = np.array([3, 8, 1, 10])
x2 = np.array([0, 1, 2, 3])
y2 = np.array([6, 2, 7, 11])

plt.plot(x1, y1, x2, y2)
plt.show()

# %%
x = np.array(list(range(1,100)))
y = np.array(list(range(201,300)))

plt.plot(x, y)

plt.title("Primera Gráfica")
plt.xlabel("Pulso Promedio")
plt.ylabel("Quema de Calorias")
# Out:
# Text(0, 0.5, 'Quema de Calorias')

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(axis = 'y')

plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.plot(x, y)

plt.grid(color ='magenta', linestyle = '--', linewidth = 0.5)

plt.show()

# %%
pi = np.pi
x = np.linspace(0 , 6 * pi,150)

coseno = np.cos(x)
seno = np.sin(x)


plt.plot(x,seno)
plt.plot(x,coseno)
plt.grid(color = 'green', linestyle = '-.')
plt.show()

# %%
x = np.linspace(0,6*np.pi,150)
coseno = np.cos(x)
seno = np.sin(x)

plt.plot(x,coseno)
plt.plot(x,seno)
plt.xlabel("Abscisas")
plt.ylabel("Coseno y Seno")
plt.title("Funciones Trigonométricas")
plt.grid(color='pink', lw=2, ls='--')
plt.show()
