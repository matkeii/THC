# %% [markdown]
# <a href="https://colab.research.google.com/github/matkeii/THC/blob/main/Clase_31_Octubre.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

#plot 2
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)

plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1) #TRABAJA 2 FILAS Y UNA SOLA COLUMNA Y MUESTRA EL PRIMER ELEMENTO
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)

plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("Salidas")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("Entradas")

plt.show()

# %%
#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("Salidas")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("Entradas")

plt.suptitle("Mi tienda")
plt.show()

# %%
por = [10,20,70]
clases = ["A","B","C"]

pit.pie(por,labels=clases,autopct="%0.1F%%")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-efbcd6dade68> in <cell line: 4>()
#       2 clases = ["A","B","C"]
#       3
# ----> 4 pit.pie(por,labels=clases,autopct="%0.1F%%")
#       5 plt.show()
#
# NameError: name 'pit' is not defined

# %% [markdown]
# ## ***Ejercicios en clase***

# %%
x = np.linspace(0,6*np.pi,150)
coseno = np.cos(x)
seno = np.sin(x)

plt.plot(x,coseno)
plt.plot(x,seno)
plt.xlabel("Abscisas")
plt.ylabel("Seno y Coseno")

plt.grid(ls='-.')

plt.suptitle("Funciones Trigonométricas.")
plt.show()

# %%
f1 = lambda x:np.cos(x)
f2 = lambda y:np.sin(x)

x = np.linspace(0,6*np.pi,100)

plt.subplot(1,2,1)
plt.plot(x,f1(x))
plt.grid("-.")
plt.title("Coseno")

plt.subplot(1,2,2)
plt.plot(x,f2(x))
plt.grid("-.")
plt.title("Seno")

plt.suptitle("Funciones Trigonométricas")
plt.show()
